# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Cleaned_Housing_Data_v1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0           0  221900.0         3       1.00         1180      5650     1.0
# 1           1  538000.0         3       2.25         2570      7242     2.0
# 2           2  180000.0         2       1.00          770     10000     1.0
# 3           3  604000.0         4       3.00         1960      5000     1.0
# 4           4  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0         NaN   0.0          3      7        1180            0.0      1955
# 1         0.0   0.0          3      7        2170          400.0      1951
# 2         0.0   0.0          3      6         770            0.0      1933
# 3         0.0   0.0          5      7        1050          910.0      1965
# 4         0.0   0.0          3      8        1680            0.0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0           0.0    98178  47.5112 -122.257           1340        5650
# 1           2.0    98125  47.7210 -122.319           1690        7639
# 2           0.0    98028  47.7379 -122.233           2720        8062
# 3           0.0    98136  47.5208 -122.393           1360        5000
# 4           0.0    98074  47.6168 -122.045           1800        7503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 20 columns):
# Unnamed: 0       21263 non-null int64
# price            21263 non-null float64
# bedrooms         21263 non-null int64
# bathrooms        21263 non-null float64
# sqft_living      21263 non-null int64
# sqft_lot         21263 non-null int64
# floors           21263 non-null float64
# waterfront       18937 non-null float64
# view             21263 non-null float64
# condition        21263 non-null int64
# grade            21263 non-null int64
# sqft_above       21263 non-null int64
# sqft_basement    21263 non-null float64
# yr_built         21263 non-null int64
# yr_renovated     21263 non-null float64
# zipcode          21263 non-null int64
# lat              21263 non-null float64
# long             21263 non-null float64
# sqft_living15    21263 non-null int64
# sqft_lot15       21263 non-null int64
# dtypes: float64(9), int64(11)
# memory usage: 3.2 MB

# %%
df.describe()
# Out:
#          Unnamed: 0         price      bedrooms     bathrooms   sqft_living  \
# count  21263.000000  2.126300e+04  21263.000000  21263.000000  21263.000000
# mean   10810.119880  5.354206e+05      3.326012      2.099163   2059.754503
# std     6236.978859  3.547799e+05      0.827807      0.749797    893.214278
# min        0.000000  7.800000e+04      1.000000      0.500000    370.000000
# 25%     5414.500000  3.200000e+05      3.000000      1.500000   1420.000000
# 50%    10815.000000  4.500000e+05      3.000000      2.250000   1900.000000
# 75%    16213.500000  6.399665e+05      4.000000      2.500000   2520.000000
# max    21596.000000  7.060000e+06      5.000000      6.750000  10040.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.126300e+04  21263.000000  18937.000000  21263.000000  21263.000000
# mean   1.505278e+04      1.491911      0.007499      0.228942      3.408926
# std    4.146123e+04      0.539395      0.086271      0.757166      0.650007
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.600000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.062300e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21263.000000  21263.000000   21263.000000  21263.000000  21263.000000
# mean       7.650849   1776.172365     277.883318   1971.141419      0.099657
# std        1.168076    814.804818     429.737148     29.342651      0.592169
# min        3.000000    370.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1550.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2190.000000     530.000000   1997.000000      0.000000
# max       13.000000   8020.000000    4820.000000   2015.000000      5.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21263.000000  21263.000000  21263.000000   21263.000000   21263.000000
# mean   98077.909937     47.559664   -122.213521    1982.070404   12734.246155
# std       53.509168      0.138839      0.141136     682.020008   27175.744967
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.469600   -122.328000    1480.000000    5100.000000
# 50%    98065.000000     47.571300   -122.229000    1830.000000    7620.000000
# 75%    98117.000000     47.678150   -122.124000    2360.000000   10078.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
#sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 19 columns):
# price            21263 non-null float64
# bedrooms         21263 non-null int64
# bathrooms        21263 non-null float64
# sqft_living      21263 non-null int64
# sqft_lot         21263 non-null int64
# floors           21263 non-null float64
# waterfront       18937 non-null float64
# view             21263 non-null float64
# condition        21263 non-null int64
# grade            21263 non-null int64
# sqft_above       21263 non-null int64
# sqft_basement    21263 non-null float64
# yr_built         21263 non-null int64
# yr_renovated     21263 non-null float64
# zipcode          21263 non-null int64
# lat              21263 non-null float64
# long             21263 non-null float64
# sqft_living15    21263 non-null int64
# sqft_lot15       21263 non-null int64
# dtypes: float64(9), int64(10)
# memory usage: 3.1 MB

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, minmax_scale
from scipy import stats

# %%
df.view.unique()
# Out:
# array([0., 3., 4., 2., 1.])

# %%
#sns.distplot(test)
plt.figure(0)

col = 'yr_renovated'

#sns.distplot(stats.boxcox(df[col])[0], axlabel = 'boxcox')
plt.figure(1)
sns.distplot(np.log1p(df[col]), axlabel = 'log')
plt.figure(2)
sns.distplot(df[col], axlabel = 'no transformation')

# %%
X = np.log1p(df.price)
X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))

# %%
X_std
# Out:
# 0        0.232053
# 1        0.428620
# 2        0.185605
# 3        0.454303
# 4        0.416757
#            ...
# 21258    0.339450
# 21259    0.362835
# 21260    0.363998
# 21261    0.362835
# 21262    0.316749
# Name: price, Length: 21263, dtype: float64

# %% [markdown]
# ### Transformations
#
# * log and scale the price, sqft_living, sqft_living, sqft_above
# * boxcox and scale sqft_lot, yr_built, sqft_lot15
# * scale bedrooms, bathrooms,  lat, long, sqft_basement, condition, grade, floors, zipcode, yr_renovated, view
#
#
# drop: waterfront

# %%
log_n_scale = ['sqft_living', 'sqft_living15', 'sqft_above']
boxcox_n_scale = ['yr_built', 'sqft_lot15','sqft_lot']
scale = ['bedrooms', 'bathrooms',  'lat', 'long', 'condition', 'grade', 'floors', 'zipcode', 'yr_renovated', 'view', 'sqft_basement']

transforms = [log_n_scale, boxcox_n_scale, scale]

# %%
for transform in transforms:
        for col in transform:
            if transform == log_n_scale:
                df[col] = np.log1p(df[col])
                
            elif transform == boxcox_n_scale:
                df[col] = stats.boxcox(df[col])[0]
                
            df[col] = minmax_scale(df[col])

df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0      0.50       0.08     0.351072  0.466447     0.0         NaN
# 1  538000.0      0.50       0.28     0.586935  0.503833     0.4         0.0
# 2  180000.0      0.25       0.08     0.221781  0.549846     0.0         0.0
# 3  604000.0      0.75       0.40     0.504819  0.447377     0.0         0.0
# 4  510000.0      0.50       0.24     0.458107  0.519766     0.0         0.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0   0.0        0.5    0.4    0.376727       0.000000  0.361635           0.0
# 1   0.0        0.5    0.4    0.574809       0.082988  0.329309           0.4
# 2   0.0        0.5    0.3    0.237989       0.000000  0.196551           0.0
# 3   0.0        1.0    0.4    0.338785       0.188797  0.447334           0.0
# 4   0.0        0.5    0.5    0.491584       0.000000  0.662874           0.0
#
#     zipcode       lat      long  sqft_living15  sqft_lot15
# 0  0.893939  0.571498  0.217608       0.441078    0.462941
# 1  0.626263  0.908959  0.166113       0.525634    0.512823
# 2  0.136364  0.936143  0.237542       0.699074    0.521418
# 3  0.681818  0.586939  0.104651       0.446476    0.441839
# 4  0.368687  0.741354  0.393688       0.548613    0.509937

# %% [markdown]
# for col in log_n_scale:
#     df[col] = np.log1p(df[col])
#     df[col] = minmax_scale(df[col])
#
# for col in boxcox_n_scale:
#     df[col] = stats.boxcox(df[col])
#     df[col] = minmax_scale(df[col])
#
# for col in log_n_scale:
#     df[col] = np.log1p(df[col])
#     df[col] = minmax_scale(df[col])

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0      0.50       0.08     0.351072  0.466447     0.0         NaN
# 1  538000.0      0.50       0.28     0.586935  0.503833     0.4         0.0
# 2  180000.0      0.25       0.08     0.221781  0.549846     0.0         0.0
# 3  604000.0      0.75       0.40     0.504819  0.447377     0.0         0.0
# 4  510000.0      0.50       0.24     0.458107  0.519766     0.0         0.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0   0.0        0.5    0.4    0.376727       0.000000  0.361635           0.0
# 1   0.0        0.5    0.4    0.574809       0.082988  0.329309           0.4
# 2   0.0        0.5    0.3    0.237989       0.000000  0.196551           0.0
# 3   0.0        1.0    0.4    0.338785       0.188797  0.447334           0.0
# 4   0.0        0.5    0.5    0.491584       0.000000  0.662874           0.0
#
#     zipcode       lat      long  sqft_living15  sqft_lot15
# 0  0.893939  0.571498  0.217608       0.441078    0.462941
# 1  0.626263  0.908959  0.166113       0.525634    0.512823
# 2  0.136364  0.936143  0.237542       0.699074    0.521418
# 3  0.681818  0.586939  0.104651       0.446476    0.441839
# 4  0.368687  0.741354  0.393688       0.548613    0.509937

# %%
df = df.drop(columns = 'waterfront')

# %%
df['price'] = np.log1p(df.price)

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  12.309987      0.50       0.08     0.351072  0.466447     0.0   0.0
# 1  13.195616      0.50       0.28     0.586935  0.503833     0.4   0.0
# 2  12.100718      0.25       0.08     0.221781  0.549846     0.0   0.0
# 3  13.311331      0.75       0.40     0.504819  0.447377     0.0   0.0
# 4  13.142168      0.50       0.24     0.458107  0.519766     0.0   0.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0        0.5    0.4    0.376727       0.000000  0.361635           0.0
# 1        0.5    0.4    0.574809       0.082988  0.329309           0.4
# 2        0.5    0.3    0.237989       0.000000  0.196551           0.0
# 3        1.0    0.4    0.338785       0.188797  0.447334           0.0
# 4        0.5    0.5    0.491584       0.000000  0.662874           0.0
#
#     zipcode       lat      long  sqft_living15  sqft_lot15
# 0  0.893939  0.571498  0.217608       0.441078    0.462941
# 1  0.626263  0.908959  0.166113       0.525634    0.512823
# 2  0.136364  0.936143  0.237542       0.699074    0.521418
# 3  0.681818  0.586939  0.104651       0.446476    0.441839
# 4  0.368687  0.741354  0.393688       0.548613    0.509937

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 18 columns):
# price            21263 non-null float64
# bedrooms         21263 non-null float64
# bathrooms        21263 non-null float64
# sqft_living      21263 non-null float64
# sqft_lot         21263 non-null float64
# floors           21263 non-null float64
# view             21263 non-null float64
# condition        21263 non-null float64
# grade            21263 non-null float64
# sqft_above       21263 non-null float64
# sqft_basement    21263 non-null float64
# yr_built         21263 non-null float64
# yr_renovated     21263 non-null float64
# zipcode          21263 non-null float64
# lat              21263 non-null float64
# long             21263 non-null float64
# sqft_living15    21263 non-null float64
# sqft_lot15       21263 non-null float64
# dtypes: float64(18)
# memory usage: 2.9 MB

# %%
df.to_csv('Cleaned_Housing_Data_v3.csv')
