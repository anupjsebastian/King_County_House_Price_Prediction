# %% [markdown]
# # Imports and Reads

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.waterfront.unique()
# Out:
# array([nan,  0.,  1.])

# %% [markdown]
# Fill in waterfront later using a lat and long

# %%
df.yr_renovated.unique()
# Out:
# array([   0., 1991.,   nan, 2002., 2010., 1992., 2013., 1994., 1978.,
#        2005., 2003., 1984., 1954., 2014., 2011., 1983., 1945., 1990.,
#        1988., 1977., 1981., 1995., 2000., 1999., 1998., 1970., 1989.,
#        2004., 1986., 2007., 1987., 2006., 1985., 2001., 1980., 1971.,
#        1979., 1997., 1950., 1969., 1948., 2009., 2015., 1974., 2008.,
#        1968., 2012., 1963., 1951., 1962., 1953., 1993., 1996., 1955.,
#        1982., 1956., 1940., 1976., 1946., 1975., 1964., 1973., 1957.,
#        1959., 1960., 1967., 1965., 1934., 1972., 1944., 1958.])

# %%
df.yr_renovated.value_counts()
# Out:
# 0.0       17011
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
#           ...
# 1946.0        1
# 1959.0        1
# 1971.0        1
# 1951.0        1
# 1954.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# make unrenovated houses into categorical (Old house and New house). bin all old houses

# %%
df.view.unique()
# Out:
# array([ 0., nan,  3.,  4.,  2.,  1.])

# %%
df.view.value_counts()
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %% [markdown]
# change view to categorical. 0 to no view

# %%
df[df.bedrooms == 33] 
df[df.bedrooms == 11]
df[df.bedrooms == 10]
df[df.bedrooms > 5]
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 209    6300000550   7/17/2014   464000.0         6       3.00         2300
# 232    9264902050  11/21/2014   315000.0         6       2.75         2940
# 239    5152100060   5/29/2014   472000.0         6       2.50         4410
# 331    2946001550   4/16/2015   279000.0         6       1.75         2240
# 486    9286000240   7/11/2014  1070000.0         6       3.50         4860
# ...           ...         ...        ...       ...        ...          ...
# 20968  2149800278  10/15/2014   343000.0         6       5.00         2732
# 21069  4449800480   3/18/2015   677790.0         6       3.00         2800
# 21170  7896300592   1/14/2015   303500.0         6       4.50         3390
# 21359  6061500100   7/17/2014  1170000.0         6       3.50         4310
# 21506   603000555    3/2/2015   462500.0         6       3.00         2390
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %% [markdown]
# ## Classifying features as categoricals, strings and numeric

# %%
categoricals = []
numeric = []
strings = []

split = 10


for col in list(df.columns):
    if df[col].dtype == 'int64' or df[col].dtype == 'float64':
        if len(df[col].unique()) < split:
            categoricals.append(col)
        else:
            numeric.append(col)
    else:
        if len(df[col].unique()) < split:
            categoricals.append(col)
        else:
            strings.append(col)
            
print('Categoricals:', categoricals)
print('Numeric:', numeric)
print('Strings:', strings)
# Out:
# Categoricals: ['floors', 'waterfront', 'view', 'condition']
# Numeric: ['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'grade', 'sqft_above', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
# Strings: ['date', 'sqft_basement']

# %% [markdown]
# Maybe drop dates. but before that convert them to date time and plot prices vs date

# %%
df.date = pd.to_datetime(df.date)

# %%
# creating columns for year and month

# %%
df.date
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df.date.dt.year

# %%
df['month'] = df.date.dt.month

# %%
df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21592   263000018 2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21595   291310100 2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# ...

# %% [markdown]
# no real variation with time so date can be dropped

# %%
# sns.set_style('ticks')
# sns.scatterplot(df.bedrooms, df.price, hue = df.floors, alpha = 0.8)
df[df['id'] == 0]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, year, month]
# Index: []
#
# [0 rows x 23 columns]

# %%
print('Categoricals:', categoricals)
print('Numeric:', numeric)
print('Strings:', strings)
# Out:
# Categoricals: ['floors', 'waterfront', 'view', 'condition']
# Numeric: ['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'grade', 'sqft_above', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
# Strings: ['date', 'sqft_basement']

# %% [markdown]
# # Notes so far
#
# ## Categoricals
#
# * floors can be numeric as they indicate some numeric quantity.
# * waterfront needs to be filled in using map data.
# * view should be numeric. the nans should be filled in with the median or mode. only 63 missing values.
# * condition should be treated as numeric. data is complete.
#
# ## Numeric
#
# * id should be dropped
# * price should be set as target
# * rows with bedrooms above 5 are dropped
# * bathrooms are ok
# * squarefeet columns are ok
# * grade is ok
# * yr_built is ok
# * yr_renovated could be binned, (renovated or not), bin the ones that are renovated based on how recent the renovation was.
# * keep coordinates and zipcode
# * drop date
#
# (also try drop zipcode, keep zipcode along with id)

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002386   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.078523   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
# sns.heatmap(df.corr().abs())

# %% [markdown]
# # Cleanup Process

# %% [markdown]
# * floors are ok
# * waterfront needs to be filled in using map data.
# * view need to be filled. the nans should be filled in with the median or mode. only 63 missing values.
# * condition is ok
#
# * id should be dropped
# * price should be set as target
# * rows with bedrooms above 5 are dropped
# * bathrooms are ok
# * squarefeet columns are ok
# * grade is ok
# * yr_built is ok
# * yr_renovated could be binned, (renovated or not), bin the ones that are renovated based on how recent the renovation was.
# * keep coordinates and zipcode
# * drop date

# %%
list(df.columns)
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15',
#  'year',
#  'month']

# %%
to_drop = ['id', 'date']

# %% [markdown]
# ### filling in view

# %%
# idx = df['view'].isna()
# idx
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21592    False
# 21593    False
# 21594    False
# 21595    False
# 21596    False
# Name: view, Length: 21265, dtype: bool

# %%
df.view.value_counts()
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %%
df['view'].fillna(0.0, inplace=True)

# %%
df.view.isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0         NaN   0.0  ...            0.0      1955
# 1      7242     2.0         0.0   0.0  ...          400.0      1951
# 2     10000     1.0         0.0   0.0  ...            0.0      1933
# 3      5000     1.0         0.0   0.0  ...          910.0      1965
# 4      8080     1.0         0.0   0.0  ...            0.0      1987
#
#    yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15  year  \
# ...

# %% [markdown]
# ### dropping houses above 5 bedrooms

# %%
idx = df[df.bedrooms > 5]

# %%
df = df.drop(idx.index)

# %%
len(df)
# Out:
# 21263

# %%
df.bedrooms.isna().sum()
# Out:
# 0

# %% [markdown]
# ### binning year renovated

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2326
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3790
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# year                0
# month               0
# dtype: int64

# %%
idx = df.yr_renovated.isna()

# %%
np.sort(df[idx].yr_built.unique())
# Out:
# array([1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#        1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921,
#        1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932,
#        1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015])

# %%
df[idx].yr_renovated = 0

# %%
df.loc[idx, 'yr_renovated']  = 0

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2326
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# year                0
# month               0
# dtype: int64

# %%
idx = df.yr_renovated != 0

# %%
idx
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 21592    False
# 21593    False
# 21594    False
# 21595    False
# 21596    False
# Name: yr_renovated, Length: 21263, dtype: bool

# %%
sum(idx)
# Out:
# 717

# %%
df[idx].yr_renovated
# Out:
# 1        1991.0
# 35       2002.0
# 95       1991.0
# 103      2010.0
# 125      1992.0
#           ...
# 19602    2004.0
# 20041    2006.0
# 20428    2009.0
# 20431    2014.0
# 20946    2007.0
# Name: yr_renovated, Length: 717, dtype: float64

# %%
df[idx].yr_renovated.describe()
# Out:
# count     717.000000
# mean     1995.935844
# std        15.695561
# min      1934.000000
# 25%      1987.000000
# 50%      2000.000000
# 75%      2008.000000
# max      2015.000000
# Name: yr_renovated, dtype: float64

# %%
pd.qcut(df[idx].yr_renovated, 5, range(1,6)).astype(int)
# Out:
# 1        2
# 35       3
# 95       2
# 103      4
# 125      2
#         ..
# 19602    4
# 20041    4
# 20428    4
# 20431    5
# 20946    4
# Name: yr_renovated, Length: 717, dtype: int64

# %%
df.loc[idx, 'yr_renovated'] = pd.qcut(df[idx].yr_renovated, 5, range(1,6)).astype(int)

# %%
df.yr_renovated.value_counts()
# Out:
# 0.0    20546
# 2.0      152
# 4.0      146
# 1.0      145
# 3.0      142
# 5.0      132
# Name: yr_renovated, dtype: int64

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0         NaN   0.0  ...            0.0      1955
# 1      7242     2.0         0.0   0.0  ...          400.0      1951
# 2     10000     1.0         0.0   0.0  ...            0.0      1933
# 3      5000     1.0         0.0   0.0  ...          910.0      1965
# 4      8080     1.0         0.0   0.0  ...            0.0      1987
#
#    yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15  year  \
# ...

# %%
df.to_csv('Cleaned_Housing_Data_vDL.csv')

# %% [markdown]
# Untouched
#      floors, condition, bathrooms, all squarefeet columns, grade, yr_built, coordinates, zipcode.
#
# Dropped
#     id, date
#
# Processed
#    * view nans filled with median (63 missing values).
#    * rows with bedrooms greater than 5 are dropped (about 300 rows out of 21k so our model could be more accurate)
#    * yr_renovated had zeros, nans and years. nans have been set to 0. all the years are binned in equal numbers from 1 to 5. So yr_renovated is now a scale from 0 to 5, 0 being not renovated and 5 being recently renovated.
#
# Still needs processing
#     waterfront - has a bunch of nans. could be filled in using map data, but still need to figure out how.
#
# If i missed any over here assume they are untouched :)

# %%
from sklearn.cluster import DBSCAN

# %%
lat_long = df[['lat','long']].to_numpy()

# %%
clustering = DBSCAN(eps=.036).fit(lat_long)

# %%
clustering.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
unique, counts = np.unique(clustering.labels_, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[   -1    10]
#  [    0 21064]
#  [    1    63]
#  [    2   117]
#  [    3    11]]
